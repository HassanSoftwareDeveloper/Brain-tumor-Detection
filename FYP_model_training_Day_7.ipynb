# %%
# %% [markdown]
# # LongiTumorSense Model Training
# **Training on MU-Glioma-Post Dataset**
# - Segmentation: nnUNet
# - Classification: 3D DenseNet
# - Survival: CoxPH Model

# %%
# !pip install monai torch torchvision nnunet pyradiomics lifelines pydicom nibabel wandb -q

# %%
import nibabel as nib
import numpy  as np
from sklearn.model_selection import train_test_split
import torch
import os
import monai
from monai.data import Dataset ,DataLoader
from monai.transforms import ( Compose , LoadImaged , EnsureChannelFirstd, ScaleIntensityd,RandRotated,RandFlipd,RandZoomd,ToTensord)
from monai.networks.nets import DenseNet121,Unet
from monai.metrics import DiceMetric
from monai.losses import DiceLoss, FocalLoss
import wandb
import pandas as pd
from lifelines import CoxPHFitter

# %%
import torch

# %%
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

print(f"Using {device} device.")
# Out:
# Using cpu device.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Data Clearner and saved into the drive**

# %%
import os
import shutil


raw_root = "/content/drive/My Drive/MU-Glioma-Post"

output_root="/content/drive/My Drive/clean_data"



imagesTr = os.path.join(output_root, "imagesTr")
labelsTr = os.path.join(output_root, "labelsTr")
os.makedirs(os.path.join(output_root, "imagesTs"), exist_ok=True)
os.makedirs(imagesTr, exist_ok=True)
os.makedirs(labelsTr, exist_ok=True)

print("Raw dataset path:", raw_root)
print("nnU-Net dataset path:", output_root)


progress_file = os.path.join(output_root, "converted_cases.txt")

if os.path.exists(progress_file):
    with open(progress_file, "r") as f:
        converted_cases = set(line.strip() for line in f)
else:
    converted_cases = set()
print(f"Found {len(converted_cases)} cases already processed.")
# Out:
# Raw dataset path: /content/drive/My Drive/MU-Glioma-Post
# nnU-Net dataset path: /content/drive/My Drive/clean_data
# Found 4 cases already processed.

# %%
def is_nifti(fname):
  return fname.endswith(".nii") or fname.endswith(".nii.gz")

# %%
mod_priority=[
      't1c','t1gd','t1ce',  # contrast-enhanced T1 variants
    't1n','t1',           # native T1
    'flair','t2f','t2flair','t2w','t2' # T2 /flair variants
]

# %%
def file_priority(fname):
  lf=fname.lower()
  for i,k in enumerate(mod_priority):
    if k in lf:
      return i
  return len(mod_priority) + hash(lf) % 1000

# %%
import re
import os
import shutil
from tqdm import tqdm
canonical_modalities = None




skipped = []
new_cases_count = 0





total_timepoints = sum(
    1 for p in sorted(os.listdir(raw_root))
    if os.path.isdir(os.path.join(raw_root, p))
    for tp in sorted(os.listdir(os.path.join(raw_root, p)))
    if os.path.isdir(os.path.join(raw_root, p, tp))
)







with tqdm(total=total_timepoints, desc="Processing cases") as pbar:
    for patient_id in sorted(os.listdir(raw_root)):
        patient_path = os.path.join(raw_root, patient_id)
        if not os.path.isdir(patient_path):
            pbar.update(1)
            continue






        for tp in sorted(os.listdir(patient_path)):
            tp_path = os.path.join(patient_path, tp)
            if not os.path.isdir(tp_path):
                pbar.update(1)
                continue



            tp_clean = re.sub(r"\s+", "_", tp)
            tp_clean = re.sub(r"[^A-Za-z0-9_-]", "_", tp_clean)
            case_id = f"{patient_id}_{tp_clean}"



            if case_id in converted_cases:
                pbar.update(1)
                continue


            files = [f for f in os.listdir(tp_path) if is_nifti(f)]
            if not files:
                skipped.append((patient_id, tp, "no nifti files"))
                pbar.update(1)
                continue



            label_candidates = [f for f in files if any(x in f.lower() for x in ["mask", "tumor", "seg", "label"])]
            if len(label_candidates) == 0:
                skipped.append((patient_id, tp, "no label found"))
                pbar.update(1)
                continue


            label_file = label_candidates[0]



            image_files = [f for f in files if f != label_file]
            if len(image_files) == 0:
                skipped.append((patient_id, tp, "no image files"))
                pbar.update(1)
                continue



            image_files_sorted = sorted(image_files, key=file_priority)
            if canonical_modalities is None:
                canonical_modalities = image_files_sorted.copy()
                print("\nDetected modality order (from first sample)")
                for idx, nm in enumerate(canonical_modalities):
                    print(f"{idx}: {nm}")
                print("If this order is wrong adjust mod_priority list in the script.")


            else:
                if len(image_files_sorted) != len(canonical_modalities):
                    skipped.append(
                        (patient_id, tp, f"modality count mismatch {len(image_files_sorted)} vs {len(canonical_modalities)}")
                    )
                    pbar.update(1)
                    continue



            for i, fname in enumerate(image_files_sorted):
                src = os.path.join(tp_path, fname)
                destination = os.path.join(imagesTr, f"{case_id}_{i:04d}.nii.gz")
                shutil.copy(src, destination)

            shutil.copy2(os.path.join(tp_path, label_file), os.path.join(labelsTr, f"{case_id}.nii.gz"))



            converted_cases.add(case_id)
            with open(progress_file, "a") as f:
                f.write(case_id + "\n")

            new_cases_count += 1
            pbar.update(1)

print(f"\nConversion finished. {len(converted_cases)} total cases processed so far.")
if skipped:
    print(f"{len(skipped)} timepoints skipped (see sample):")
    for s in skipped[:10]:
        print(" ", s)

print(f"imagesTr files: {len(os.listdir(imagesTr))}, labelsTr files: {len(os.listdir(labelsTr))}")
print(f"Newly processed this run: {new_cases_count}")

# %%
# !rm -r /content/nnUNet_raw_data_base

# %% [markdown]
# **Get clean data from drive into local colab  with correct file naming structure and create json.data file according to nnUnet formet**

# %%
import os
import re
import json
import shutil
import nibabel as nib
import numpy as np
from tqdm import tqdm
from collections import defaultdict
from pathlib import Path


config = {
    'drive_root': "/content/drive/MyDrive/clean_data",
    'local_root': "/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post",
    'image_pattern': r"(PatientID_\d+)_Timepoint_(\d+)_(\d{4})\.nii\.gz",
    'label_pattern': r"(PatientID_\d+)_Timepoint_(\d+)\.nii\.gz",
    'task_name': "MU-Glioma-Post",
    'expected_modalities': ["0000", "0001", "0002", "0003"],
    'create_test_folder': False,
    'handle_missing_modalities': "create_empty",
    'strict_validation': True,
    'label_classes': {"0": "background", "1": "tumor"},
}

modality_map = {
    "0000": {"suffix": "0000", "name": "t1gd", "order": 0},
    "0001": {"suffix": "0001", "name": "t1", "order": 1},
    "0002": {"suffix": "0002", "name": "t2", "order": 2},
    "0003": {"suffix": "0003", "name": "flair", "order": 3}
}


paths = {
    'source_images': Path(config['drive_root']) / "imagesTr",
    'source_labels': Path(config['drive_root']) / "labelsTr",
    'dest_images': Path(config['local_root']) / "imagesTr",
    'dest_labels': Path(config['local_root']) / "labelsTr"
}
paths['dest_images'].mkdir(parents=True, exist_ok=True)
paths['dest_labels'].mkdir(parents=True, exist_ok=True)

if config['create_test_folder']:
    paths['dest_imagesTs'] = Path(config['local_root']) / "imagesTs"
    paths['dest_imagesTs'].mkdir(parents=True, exist_ok=True)


def create_empty_volume(reference_path: Path, output_path: Path):
    """Create empty NIfTI matching reference geometry"""
    try:
        ref_img = nib.load(str(reference_path))
        empty_data = np.zeros(ref_img.shape, dtype=np.float32)
        empty_img = nib.Nifti1Image(empty_data, ref_img.affine, ref_img.header)
        nib.save(empty_img, str(output_path))
        return True
    except Exception as e:
        print(f"[ERROR] Failed to create empty volume: {output_path} | {e}")
        return False


case_counter = 1
patient_mapping = {}
case_data = defaultdict(dict)
warnings = []
errors = []

#process images
for fname in tqdm(list(paths['source_images'].iterdir()), desc="Processing images"):
    if not fname.name.endswith(".nii.gz"):
        continue
    match = re.match(config['image_pattern'], fname.name)
    if not match:
        warnings.append(f"SKIPPED: Invalid image filename - {fname.name}")
        continue
    patient_id, _, modality_idx = match.groups()
    if patient_id not in patient_mapping:
        case_id = f"Case_{case_counter:04d}"
        patient_mapping[patient_id] = case_id
        case_counter += 1
    case_id = patient_mapping[patient_id]
    modality_info = modality_map.get(modality_idx)
    if not modality_info:
        warnings.append(f"SKIPPED: Unknown modality {modality_idx} in {fname.name}")
        continue
    dest_path = paths['dest_images'] / f"{case_id}_{modality_info['suffix']}.nii.gz"
    shutil.copyfile(str(fname), str(dest_path))
    case_data[case_id].setdefault("modalities", []).append(modality_info)
    if "reference_volume" not in case_data[case_id]:
        case_data[case_id]["reference_volume"] = dest_path

#process labels
for fname in tqdm(list(paths['source_labels'].iterdir()), desc="Processing labels"):
    if not fname.name.endswith(".nii.gz"):
        continue
    match = re.match(config['label_pattern'], fname.name)
    if not match:
        warnings.append(f"SKIPPED: Invalid label filename - {fname.name}")
        continue
    patient_id, _ = match.groups()
    if patient_id not in patient_mapping:
        errors.append(f"ORPHAN LABEL: {fname.name}")
        continue
    case_id = patient_mapping[patient_id]
    dest_path = paths['dest_labels'] / f"{case_id}.nii.gz"
    shutil.copyfile(str(fname), str(dest_path))
    case_data[case_id]["label_exists"] = True

#  handle missing modalities
cases_to_remove = []
for case_id, data in case_data.items():
    if "modalities" not in data or not data.get("label_exists", False):
        cases_to_remove.append(case_id)
        continue
    found_modalities = {m["suffix"] for m in data["modalities"]}
    missing = set(config['expected_modalities']) - found_modalities
    if missing:
        if config['handle_missing_modalities'] == "skip_case":
            cases_to_remove.append(case_id)
            warnings.append(f"REMOVING CASE: {case_id} missing {sorted(missing)}")
        elif config['handle_missing_modalities'] == "create_empty":
            for mod in missing:
                empty_path = paths['dest_images'] / f"{case_id}_{mod}.nii.gz"
                if create_empty_volume(data["reference_volume"], empty_path):
                    data["modalities"].append(modality_map[mod])
                    warnings.append(f"CREATED EMPTY: {case_id}_{mod}.nii.gz")
                else:
                    errors.append(f"EMPTY VOLUME FAILED: {case_id}_{mod}.nii.gz")
                    cases_to_remove.append(case_id)
                    break

for cid in set(cases_to_remove):
    case_data.pop(cid, None)

# dataset.json file
modality_list = sorted(modality_map.values(), key=lambda x: x['order'])
is_multimodal = len(modality_list) > 1

dataset_json = {
    "name": config['task_name'],
    "description": "Post-operative glioma segmentation",
    "reference": "Your reference here",
    "licence": "Your license here",
    "release": "1.0",
    "modality": {str(i): m["name"] for i, m in enumerate(modality_list)},
    "labels": config['label_classes'],
    "numTraining": len([c for c in case_data.values() if c.get("label_exists")]),
    "numTest": 0,
    "training": [],
    "test": []
}

for case_id, data in case_data.items():
    if not data.get("label_exists"):
        continue
    image_paths = [f"./imagesTr/{case_id}_{m['suffix']}.nii.gz" for m in modality_list]
    entry = {
        "image": image_paths if is_multimodal else image_paths[0],
        "label": f"./labelsTr/{case_id}.nii.gz"
    }
    dataset_json["training"].append(entry)

# post validation

for i, case in enumerate(dataset_json["training"][:5]):
    assert (is_multimodal and isinstance(case['image'], list)) or (not is_multimodal and isinstance(case['image'], str)), \
        f"Case {i} modality type mismatch"
    for img_path in case['image'] if is_multimodal else [case['image']]:
        if not (paths['dest_images'] / Path(img_path).name).exists():
            raise FileNotFoundError(f"Missing image: {img_path}")
    if not (paths['dest_labels'] / Path(case['label']).name).exists():
        raise FileNotFoundError(f"Missing label: {case['label']}")

# save dataset.json
final_path = Path(config['local_root']) / "dataset.json"
with open(final_path, 'w') as f:
    json.dump(dataset_json, f, indent=4, ensure_ascii=False)

print(f"\nDATASET CREATION SUCCESSFUL! Total training cases: {len(dataset_json['training'])}")
print(f"Modality order: {[m['name'] for m in modality_list]}")
if warnings:
    print("\nWarnings:")
    for w in warnings:
        print(f" - {w}")
if errors:
    print("\nErrors:")
    for e in errors:
        print(f" - {e}")
# Out:
# Processing images: 100%|██████████| 2376/2376 [01:55<00:00, 20.55it/s]
# Processing labels: 100%|██████████| 594/594 [00:05<00:00, 112.35it/s]
# DATASET CREATION SUCCESSFUL! Total training cases: 203
# Modality order: ['t1gd', 't1', 't2', 'flair']

# %% [markdown]
# **it converts your raw dataset filenames into the exact nnU-Net format**
# Case_0001_T1.nii.gz → Case_0001_0000.nii.gz
# Case_0001_FLAIR.nii.gz → Case_0001_0003.nii.gz

# %% [markdown]
# **verify your current folder structure and file consistency**

# %%
import os
from pathlib import Path
import shutil


root = Path("/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post")
imagesTr = root / "imagesTr"
labelsTr = root / "labelsTr"



modality_map = {
    "T1": "0000",
    "T2": "0001",
    "T1ce": "0002",
    "FLAIR": "0003"
}

# rename images

for f in imagesTr.glob("*.nii.gz"):
    fname = f.name
    case_id = fname.split("_")[0] + "_" + fname.split("_")[1]
    modality = None

    for key in modality_map.keys():
        if key in fname:
            modality = modality_map[key]
            break

    if modality is None:
        print(f" Skipping (unknown modality): {fname}")
        continue

    new_name = f"{case_id}_{modality}.nii.gz"
    new_path = imagesTr / new_name

    print(f"Renaming: {fname} → {new_name}")
    shutil.move(str(f), str(new_path))

# rename labels

for f in labelsTr.glob("*.nii.gz"):
    fname = f.name
    case_id = fname.split("_")[0] + "_" + fname.split("_")[1]  # e.g. Case_0001
    new_name = f"{case_id}.nii.gz"
    new_path = labelsTr / new_name

    if fname != new_name:
        print(f"Renaming label: {fname} → {new_name}")
        shutil.move(str(f), str(new_path))

print("\n Renaming complete! Your dataset should now follow nnUNet format.")

# %% [markdown]
# **Validating that dataset actually matches nnU-Net requirements before training**

# %%
from pathlib import Path


local_root = Path("/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post")
expected_modalities = ["0000", "0001", "0002", "0003"]

imagesTr = local_root / "imagesTr"
labelsTr = local_root / "labelsTr"
imagesTs = local_root / "imagesTs"


print("Verifying training data...")

cases = set("_".join(f.stem.replace(".nii","").split("_")[:2])
            for f in imagesTr.glob("*.nii.gz"))

errors = []

for case in cases:

    for mod in expected_modalities:
        img_path = imagesTr / f"{case}_{mod}.nii.gz"
        if not img_path.exists():
            errors.append(f"Missing modality {mod} for case {case}")

    label_path = labelsTr / f"{case}.nii.gz"
    if not label_path.exists():
        errors.append(f"Missing label for case {case}")

# verify test data
if imagesTs.exists():
    print("Verifying test data...")
    test_cases = set("_".join(f.stem.replace(".nii","").split("_")[:2])
                     for f in imagesTs.glob("*.nii.gz"))
    for case in test_cases:
        for mod in expected_modalities:
            img_path = imagesTs / f"{case}_{mod}.nii.gz"
            if not img_path.exists():
                errors.append(f"Missing modality {mod} for test case {case}")

# report
if not errors:
    print("All files verified! ")
else:
    print("Warnings/Errors found:")
    for e in errors:
        print(f" - {e}")

print(f"Total training cases: {len(cases)}")
if imagesTs.exists():
    print(f"Total test cases: {len(test_cases)}")
# Out:
# Verifying training data...
# All files verified!
# Total training cases: 203

# %% [markdown]
# **After Disconnect:**

# %%
# !pip install monai torch torchvision nnunet pyradiomics lifelines pydicom nibabel wandb -q

# %% [markdown]
# **Install a Python package directly from its GitHub source code, not from the normal package store (PyPI).”**

# %%
# !pip install git+https://github.com/MIC-DKFZ/nnUNet.git

# %% [markdown]
# **This function loads an MRI file, converts it to a NumPy array, and scales all values to between 0 and 1 for easier analysis.**

# %%
import nibabel as nib
import numpy  as np

def load_and_preprocess(patient_path):
    img = nib.load(patient_path)
    data = img.get_fdata()
    data = (data - np.min(data)) / (np.max(data) - np.min(data))
    return data

# %% [markdown]
# **delete 0 bytes files**

# %%
import os

def clean_zero_byte_files(folder_path, verbose=True):
    """Safely delete 0-byte files and verify deletions.

    Args:
        folder_path: Path to directory to clean
        verbose: Whether to print deletion messages

    Returns:
        tuple: (deleted_files, failed_deletions)
    """
    deleted_files = []
    failed_deletions = []

    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)

            try:

                if os.path.isfile(file_path) and os.path.getsize(file_path) == 0:
                    if verbose:
                        print(f"Deleting 0-byte file: {file_path}")

                    os.remove(file_path)


                    if not os.path.exists(file_path):
                        deleted_files.append(file_path)
                    else:
                        failed_deletions.append(file_path)
                        if verbose:
                            print(f"Failed to delete: {file_path}")

            except Exception as e:
                failed_deletions.append(file_path)
                if verbose:
                    print(f"Error processing {file_path}: {str(e)}")

    return deleted_files, failed_deletions


deleted_images, failed_images = clean_zero_byte_files("/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post/imagesTr")
deleted_labels, failed_labels = clean_zero_byte_files("/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post/labelsTr")

print(f"\nResults:")
print(f"Deleted {len(deleted_images)} image files")
print(f"Failed to delete {len(failed_images)} image files")
print(f"Deleted {len(deleted_labels)} label files")
print(f"Failed to delete {len(failed_labels)} label files\n")

if failed_images or failed_labels:
    print("Warning: Some files couldn't be deleted. Check permissions.")
# Out:
# Results:
# Deleted 0 image files
# Failed to delete 0 image files
# Deleted 0 label files
# Failed to delete 0 label files

# %% [markdown]
# **this is used for skipped bad , unreachable ,missing samples instead of crashing**

# %%
from monai.transforms import LoadImaged
from monai.data import Dataset as MonaiDataset,DataLoader
class SafeDataset(MonaiDataset):
    def __getitem__(self, index):
        item = self.data[index]
        try:
            if self.transform is not None:
                transformed_item = self.transform(item)
                if transformed_item is not None:
                    return transformed_item
                else:
                    image=item.get("image","unknown")
                    print(f"Skipping sample at index: {index}:{image} (Transform returned None)")
                    return None

            return item

        except (FileNotFoundError, nib.filebasedimages.ImageFileError, RuntimeError)  as e:
              image=item.get("image","unknown")
              print(f"Skipping sample at index: {index}:{image} ({e})")
              return None
        except Exception as e:
             image= item.get("image","unknown")
             print(f"Skipping sample at index:  {index} due to unexpected error: {image} ({e})")
             return None

# %% [markdown]
# **t checks the batch list, kicks out the None entries, and only lets valid data into the collate party. **

# %%
from torch.utils.data._utils.collate import default_collate
def collate_skip_none(batch):
    batch = [item for item in batch if item is not None]
    if not batch:
        return []
    return default_collate(batch)

# %% [markdown]
# **Load images → put channel first → convert to PyTorch tensor.**

# %%
from monai.transforms import Compose

transform_basic=Compose([
    LoadImaged(keys=["image"],allow_missing_keys=True),
    EnsureChannelFirstd(keys=["image"]),
    ToTensord(keys=["image"])

])

# %%
batch_size=4
train_dataset_basic=SafeDataset(data=train_files,transform=transform_basic)
train_loader_basic=DataLoader(train_dataset_basic,batch_size=batch_size, collate_fn=collate_skip_none, shuffle=True)
batch_shape=next(iter(train_loader_basic))["image"].shape
print("Getting batches of shape:",batch_shape)
# Out:
# Getting batches of shape: torch.Size([4, 4, 240, 240, 155])

# %% [markdown]
# **check original file in drive**

# %%
import torch
from tqdm import tqdm
import os

def get_mean_std(dataset_loader_basic, resume_file=None, nonzero=True):
    """
    Compute per-channel mean and std from a DataLoader that yields dicts with key 'image'.

    Args:
        dataset_loader_basic: PyTorch DataLoader returning batches with ["image"] tensors
                              of shape [B, C, H, W] or [B, C, D, H, W]
        resume_file (str or None): Optional file to store the last processed batch index for resuming.
        nonzero (bool): If True, compute statistics only over nonzero voxels (ignores background).

    Returns:
        mean (torch.Tensor): Per-channel mean values.
        std (torch.Tensor): Per-channel standard deviations.
    """
    start_index = 0
    if resume_file is not None and os.path.exists(resume_file):
        with open(resume_file, "r") as f:
            start_index = int(f.read().strip() or 0)
        print(f"Resuming from batch index {start_index}...")

    first_batch = next(iter(dataset_loader_basic))
    num_channels = first_batch["image"].shape[1]

    if nonzero:
        channels_sum = torch.zeros(num_channels)
        channels_squared_sum = torch.zeros(num_channels)
        voxel_counts = torch.zeros(num_channels)
    else:
        channels_sum = torch.zeros(num_channels)
        channels_squared_sum = torch.zeros(num_channels)
        num_batches = 0

    for idx, batch in enumerate(tqdm(dataset_loader_basic, desc="Computing mean/std", unit="batch")):
        if idx < start_index:
            continue
        try:
            data = batch["image"].float()

            if nonzero:
                for c in range(num_channels):
                    mask = data[:, c] != 0
                    vals = data[:, c][mask]
                    if vals.numel() > 0:
                        channels_sum[c] += vals.sum()
                        channels_squared_sum[c] += (vals ** 2).sum()
                        voxel_counts[c] += vals.numel()
            else:
                dims = list(range(0, data.ndim))
                dims.remove(1)
                channels_sum += data.mean(dim=dims)
                channels_squared_sum += (data ** 2).mean(dim=dims)
                num_batches += 1

            if resume_file is not None:
                with open(resume_file, "w") as f:
                    f.write(str(idx + 1))

        except Exception as e:
            print(f"Error processing batch {idx}: {e}")

    if nonzero:
        if (voxel_counts == 0).any():
            raise ValueError("Some channels have no nonzero voxels.")
        mean = channels_sum / voxel_counts
        std = torch.sqrt(channels_squared_sum / voxel_counts - mean ** 2)
    else:
        if num_batches == 0:
            raise ValueError("No valid images found in the dataset.")
        mean = channels_sum / num_batches
        std = torch.sqrt(channels_squared_sum / num_batches - mean ** 2)

    return mean, std

# %%
mean, std = get_mean_std(train_loader_basic,resume_file=None)
print("Mean:", mean)
print("Std:", std)
# Out:
# Computing mean/std:  66%|██████▋   | 79/119 [08:13<04:14,  6.36s/batch]
# Skipping sample at index: 261:['/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0000.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0001.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0002.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0003.nii.gz'] (applying transform <monai.transforms.io.dictionary.LoadImaged object at 0x7a4f006b15d0>)
# Computing mean/std: 100%|██████████| 119/119 [12:22<00:00,  6.24s/batch]
# Mean: tensor([305.7782, 271.5573, 247.0512, 447.8155])
# Std: tensor([218.4011, 160.3656, 143.3827, 233.6108])

# %%
from monai.transforms import Compose, LoadImaged, EnsureChannelFirstd, ScaleIntensityd, NormalizeIntensityd, RandRotated, RandFlipd, RandZoomd, ToTensord

train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    # ScaleIntensityd(keys=["image"]),
    NormalizeIntensityd(
        keys=["image"],
        subtrahend=mean.tolist(),
        divisor=std.tolist(),
        channel_wise=True,
        nonzero=True
    ),
    RandRotated(keys=["image", "label"], range_x=0.3, prob=0.5),
    RandFlipd(keys=["image", "label"], prob=0.5),
    RandZoomd(keys=["image", "label"], min_zoom=0.9, max_zoom=1.1, prob=0.5),
    ToTensord(keys=["image", "label"]),
])

test_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    # ScaleIntensityd(keys=["image"]),
    NormalizeIntensityd(
        keys=["image"],
        subtrahend=mean.tolist(),
        divisor=std.tolist(),
        channel_wise=True,
        nonzero=True
    ),
    ToTensord(keys=["image", "label"]),
])

# %%
batch_size=4
train_dataset_norm =SafeDataset(data=train_files,transform=train_transforms)
dataset_loader_norm=DataLoader(train_dataset_norm,batch_size=batch_size, collate_fn=collate_skip_none)
batch = next(iter(dataset_loader_norm))
if batch:
    batch_shape=batch["image"].shape
    print("Getting batches of shape:",batch_shape)
else:
    print("No valid batches were loaded.")
# Out:
# Getting batches of shape: torch.Size([4, 4, 240, 240, 155])

# %%
norm_mean, norm_std = get_mean_std(dataset_loader_norm,resume_file=None)

print(f"Mean: {norm_mean}")
print(f"Standard deviation: {norm_std}")
# Out:
# Computing mean/std:  55%|█████▍    | 65/119 [22:13<17:56, 19.93s/batch]
# Skipping sample at index: 261:['/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0000.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0001.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0002.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0021_Timepoint_6_0003.nii.gz'] (applying transform <monai.transforms.io.dictionary.LoadImaged object at 0x7a4f004a7cd0>)
# Computing mean/std: 100%|██████████| 119/119 [39:41<00:00, 20.01s/batch]
# Mean: tensor([0.0047, 0.0046, 0.0091, 0.0047])
# Standard deviation: tensor([0.9846, 0.9852, 0.9753, 0.9688])

# %%
batch_size=2
test_dataset_norm=SafeDataset(data=test_files,transform=test_transforms)
dataset_loader_test_norm=DataLoader(test_dataset_norm,batch_size=batch_size,collate_fn=collate_skip_none,shuffle=False)
batch_shape=next(iter(dataset_loader_test_norm))["image"].shape
print("Getting batches of shape:",batch_shape)
print(type(test_dataset_norm))
# Out:
# Getting batches of shape: torch.Size([2, 4, 240, 240, 155])
# <class '__main__.SafeDataset'>

# %%
norm_mean, norm_std = get_mean_std(dataset_loader_test_norm)

print(f"Mean: {norm_mean}")
print(f"Standard deviation: {norm_std}")
# Out:
# Computing mean/std:  90%|█████████ | 54/60 [03:36<00:22,  3.71s/batch]
# Skipping sample at index: 109:['/content/clean_data_local/imagesTr/PatientID_0006_Timepoint_6_0000.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0006_Timepoint_6_0001.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0006_Timepoint_6_0002.nii.gz', '/content/clean_data_local/imagesTr/PatientID_0006_Timepoint_6_0003.nii.gz'] (applying transform <monai.transforms.io.dictionary.LoadImaged object at 0x7a4f006a8690>)
# Computing mean/std: 100%|██████████| 60/60 [03:58<00:00,  3.97s/batch]
# Mean: tensor([0.2668, 0.2856, 0.2744, 0.2978])
# Standard deviation: tensor([0.8363, 0.7954, 0.8210, 0.8185])

# %%
print(type(dataset_loader_norm))
print(type(dataset_loader_test_norm))
# Out:
# <class 'monai.data.dataloader.DataLoader'>
# <class 'monai.data.dataloader.DataLoader'>

# %%
from torch.utils.data import random_split
length_dataset = len(train_dataset_norm)
length_train = int(length_dataset * 0.8)
length_remaining = length_dataset - length_train
train_subset, remaining_subset = random_split(train_dataset_norm, [length_train, length_remaining])

percent_train = np.round(100 * len(train_subset) / length_dataset, 2)

print(f"Train data is {percent_train}% of full data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1652035311.py in <cell line: 0>()
#       1 from torch.utils.data import random_split
# ----> 2 length_dataset = len(train_dataset_norm)
#       3 length_train = int(length_dataset * 0.8)
#       4 length_remaining = length_dataset - length_train
#       5 train_subset, remaining_subset = random_split(train_dataset_norm, [length_train, length_remaining])
#
# NameError: name 'train_dataset_norm' is not defined

# %%
length_dataset_test = len(test_dataset_norm)
length_test = int(length_dataset_test * 0.2)
length_remaining_test = length_dataset_test - length_test

test_subset, remaining_subset_test = random_split(test_dataset_norm, [length_test, length_remaining_test])

percent_test = np.round(100 * len(test_subset) / length_dataset_test, 2)

print(f"Test data is {percent_test}% of full test data")
# Out:
# Test data is 19.33% of full test data

# %% [markdown]
# **# Convert dataset to nnUNet format**

# %%
import os
os.environ['nnUNet_raw_data_base'] = '/content/nnUNet_raw_data_base'
os.environ['nnUNet_preprocessed'] = '/content/nnUNet_preprocessed'
os.environ['RESULTS_FOLDER'] = '/content/nnUNet_results'


os.makedirs('/content/nnUNet_raw_data_base', exist_ok=True)
os.makedirs('/content/nnUNet_preprocessed', exist_ok=True)
os.makedirs('/content/nnUNet_results', exist_ok=True)

print("nnUNet_raw_data_base =", os.environ['nnUNet_raw_data_base'])
print("nnUNet_preprocessed =", os.environ['nnUNet_preprocessed'])
print("RESULTS_FOLDER =", os.environ['RESULTS_FOLDER'])
# Out:
# nnUNet_raw_data_base = /content/nnUNet_raw_data_base
# nnUNet_preprocessed = /content/nnUNet_preprocessed
# RESULTS_FOLDER = /content/nnUNet_results

# %% [markdown]
# **inshallah ho jhaye ga**

# %%
import os, json

task_name = "Task001_MU-Glioma-Post"
base = f"/content/nnUNet_raw_data_base/nnUNet_raw_data/{task_name}"
imagesTr = os.path.join(base, "imagesTr")
labelsTr = os.path.join(base, "labelsTr")


cases = sorted([
    f.replace("_0000.nii.gz", "")
    for f in os.listdir(imagesTr) if f.endswith("_0000.nii.gz")
])

dataset = {
    "name": "MU-Glioma-Post",
    "description": "Post-operative glioma segmentation",
    "reference": "Your reference here",
    "licence": "Your license here",
    "release": "1.0",
    "modality": {
        "0": "t1gd",
        "1": "t1",
        "2": "t2",
        "3": "flair"
    },
    "labels": {
        "0": "background",
        "1": "tumor",
        "2": "edema",
        "3": "enhancing_tumor",
        "4": "necrosis"



    },
    "numTraining": len(cases),
    "numTest": 0,
    "training": [],
    "test": []
}


for case in cases:
    dataset["training"].append({
        "image": f"./imagesTr/{case}.nii.gz",
        "label": f"./labelsTr/{case}.nii.gz"
    })

# save
with open(os.path.join(base, "dataset.json"), "w") as f:
    json.dump(dataset, f, indent=4)

print(f"✅ dataset.json created with {len(cases)} training cases")
# Out:
# ✅ dataset.json created with 203 training cases

# %% [markdown]
# **This script converts all multi-class tumor labels into a single binary tumor label, ensuring nnU-Net will treat it as a binary segmentation task.**

# %%
import os
import nibabel as nib
import numpy as np

label_dir = "/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post/labelsTr"

for fname in os.listdir(label_dir):
    if fname.endswith(".nii.gz"):
        path = os.path.join(label_dir, fname)
        img = nib.load(path)
        data = img.get_fdata().astype(np.uint8)

        # remap all labels >1 to 1
        data[data > 1] = 1

        new_img = nib.Nifti1Image(data, img.affine, img.header)
        nib.save(new_img, path)

print(" Labels cleaned: all values >1 mapped to 1")
# Out:
# ✅ Labels cleaned: all values >1 mapped to 1

# %%
# !cd /content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post/labelsTr && \
for f in *.nii.gz.nii.gz; do mv "$f" "${f%.nii.gz}"; done

# %% [markdown]
# **verification function**
#
# Directly validates dataset.json: Ensures your JSON file matches the actual disk structure.
#
# Catches mismatches: Sometimes renaming and dataset.json creation get out of sync — this flags them.
#
# Guarantees nnU-Net won’t fail later: Preprocessing requires dataset.json to be perfectly aligned with real files.

# %%
import os, json

base = "/content/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MU-Glioma-Post"
with open(os.path.join(base, "dataset.json")) as f:
    dataset = json.load(f)

print("Num cases in dataset.json:", dataset["numTraining"])
print("First 3 cases:")
for case in dataset["training"][:3]:
    print(case)

# Check matching files actually exist
for case in dataset["training"]:
    case_id = os.path.basename(case["image"]).replace(".nii.gz", "")
    for m in range(4):
        img_path = os.path.join(base, "imagesTr", f"{case_id}_{m:04d}.nii.gz")
        if not os.path.isfile(img_path):
            print("❌ Missing modality:", img_path)
    lbl_path = os.path.join(base, "labelsTr", f"{case_id}.nii.gz")
    if not os.path.isfile(lbl_path):
        print("❌ Missing label:", lbl_path)
# Out:
# Num cases in dataset.json: 203
# First 3 cases:
# {'image': './imagesTr/Case_0001.nii.gz', 'label': './labelsTr/Case_0001.nii.gz'}
# {'image': './imagesTr/Case_0002.nii.gz', 'label': './labelsTr/Case_0002.nii.gz'}
# {'image': './imagesTr/Case_0003.nii.gz', 'label': './labelsTr/Case_0003.nii.gz'}

# %%
# !nnUNet_plan_and_preprocess -t 1 --verify_dataset_integrity
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# Verifying training set
# checking case Case_0001
# checking case Case_0002
# checking case Case_0003
# checking case Case_0004
# checking case Case_0005
# checking case Case_0006
# checking case Case_0007
# checking case Case_0008
# checking case Case_0009
# checking case Case_0010
# checking case Case_0011
# checking case Case_0012
# checking case Case_0013
# checking case Case_0014
# checking case Case_0015
# checking case Case_0016
# checking case Case_0017
# checking case Case_0018
# checking case Case_0019
# checking case Case_0020
# checking case Case_0021
# checking case Case_0022
# checking case Case_0023
# checking case Case_0024
# checking case Case_0025
# checking case Case_0026
# checking case Case_0027
# checking case Case_0028
# checking case Case_0029
# checking case Case_0030
# checking case Case_0031
# checking case Case_0032
# checking case Case_0033
# checking case Case_0034
# checking case Case_0035
# checking case Case_0036
# checking case Case_0037
# checking case Case_0038
# checking case Case_0039
# checking case Case_0040
# checking case Case_0041
# checking case Case_0042
# checking case Case_0043
# checking case Case_0044
# checking case Case_0045
# checking case Case_0046
# checking case Case_0047
# checking case Case_0048
# checking case Case_0049
# checking case Case_0050
# checking case Case_0051
# checking case Case_0052
# checking case Case_0053
# checking case Case_0054
# checking case Case_0055
# checking case Case_0056
# checking case Case_0057
# checking case Case_0058
# checking case Case_0059
# checking case Case_0060
# checking case Case_0061
# checking case Case_0062
# checking case Case_0063
# checking case Case_0064
# checking case Case_0065
# checking case Case_0066
# checking case Case_0067
# checking case Case_0068
# checking case Case_0069
# checking case Case_0070
# checking case Case_0071
# checking case Case_0072
# checking case Case_0073
# checking case Case_0074
# checking case Case_0075
# checking case Case_0076
# checking case Case_0077
# checking case Case_0078
# checking case Case_0079
# checking case Case_0080
# checking case Case_0081
# checking case Case_0082
# checking case Case_0083
# checking case Case_0084
# checking case Case_0085
# checking case Case_0086
# checking case Case_0087
# checking case Case_0088
# checking case Case_0089
# checking case Case_0090
# checking case Case_0091
# checking case Case_0092
# checking case Case_0093
# checking case Case_0094
# checking case Case_0095
# checking case Case_0096
# checking case Case_0097
# checking case Case_0098
# checking case Case_0099
# checking case Case_0100
# checking case Case_0101
# checking case Case_0102
# checking case Case_0103
# checking case Case_0104
# checking case Case_0105
# checking case Case_0106
# checking case Case_0107
# checking case Case_0108
# checking case Case_0109
# checking case Case_0110
# checking case Case_0111
# checking case Case_0112
# checking case Case_0113
# checking case Case_0114
# checking case Case_0115
# checking case Case_0116
# checking case Case_0117
# checking case Case_0118
# checking case Case_0119
# checking case Case_0120
# checking case Case_0121
# checking case Case_0122
# checking case Case_0123
# checking case Case_0124
# checking case Case_0125
# checking case Case_0126
# checking case Case_0127
# checking case Case_0128
# checking case Case_0129
# checking case Case_0130
# checking case Case_0131
# checking case Case_0132
# checking case Case_0133
# checking case Case_0134
# checking case Case_0135
# checking case Case_0136
# checking case Case_0137
# checking case Case_0138
# checking case Case_0139
# checking case Case_0140
# checking case Case_0141
# checking case Case_0142
# checking case Case_0143
# checking case Case_0144
# checking case Case_0145
# checking case Case_0146
# checking case Case_0147
# checking case Case_0148
# checking case Case_0149
# checking case Case_0150
# checking case Case_0151
# checking case Case_0152
# checking case Case_0153
# checking case Case_0154
# checking case Case_0155
# checking case Case_0156
# checking case Case_0157
# checking case Case_0158
# checking case Case_0159
# checking case Case_0160
# checking case Case_0161
# checking case Case_0162
# checking case Case_0163
# checking case Case_0164
# checking case Case_0165
# checking case Case_0166
# checking case Case_0167
# checking case Case_0168
# checking case Case_0169
# checking case Case_0170
# checking case Case_0171
# checking case Case_0172
# checking case Case_0173
# checking case Case_0174
# checking case Case_0175
# checking case Case_0176
# checking case Case_0177
# checking case Case_0178
# checking case Case_0179
# checking case Case_0180
# checking case Case_0181
# checking case Case_0182
# checking case Case_0183
# checking case Case_0184
# checking case Case_0185
# checking case Case_0186
# checking case Case_0187
# checking case Case_0188
# checking case Case_0189
# checking case Case_0190
# checking case Case_0191
# checking case Case_0192
# checking case Case_0193
# checking case Case_0194
# checking case Case_0195
# checking case Case_0196
# checking case Case_0197
# checking case Case_0198
# checking case Case_0199
# checking case Case_0200
# checking case Case_0201
# checking case Case_0202
# checking case Case_0203
# Verifying label values
# Expected label values are [0, 1, 2, 3, 4]
# Labels OK
# Dataset OK
# Case_0001
# Case_0008
# Case_0015
# Case_0022
# Case_0029
# Case_0036
# Case_0043
# Case_0050
# before crop: (4, 155, 240, 240) after crop: (4, 140, 167, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 144, 156, 156) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 167, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 170, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 158, 138) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 168, 144) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 181, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 148, 184, 133) spacing: [1. 1. 1.]
#
# Case_0002
# Case_0023
# Case_0030
# Case_0037
# Case_0044
# Case_0009
# Case_0051
# Case_0016
# before crop: (4, 155, 240, 240) after crop: (4, 137, 159, 124) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 177, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 172, 127) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 174, 129) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 169, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 134, 165, 142) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 166, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 132, 121) spacing: [1. 1. 1.]
#
# Case_0003
# Case_0024
# Case_0010
# Case_0038
# Case_0045
# Case_0031
# Case_0052
# Case_0017
# before crop: (4, 155, 240, 240) after crop: (4, 133, 171, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 157, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 169, 144) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 180, 149) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 170, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 144, 153, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 173, 129) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 130, 159, 134) spacing: [1. 1. 1.]
#
# Case_0004
# Case_0025
# Case_0032
# Case_0046
# Case_0011
# Case_0039
# Case_0053
# Case_0018
# before crop: (4, 155, 240, 240) after crop: (4, 137, 176, 141) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 134, 168, 126) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 133, 158, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 186, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 157, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 170, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 135, 171, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 149, 130) spacing: [1. 1. 1.]
#
# Case_0026
# Case_0005
# Case_0047
# Case_0040
# Case_0012
# Case_0033
# Case_0019
# before crop: (4, 155, 240, 240) after crop: (4, 138, 168, 132) spacing: [1. 1. 1.]
#
# Case_0054
# before crop: (4, 155, 240, 240) after crop: (4, 140, 177, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 161, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 162, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 168, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 135, 169, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 171, 133) spacing: [1. 1. 1.]
#
# Case_0027
# before crop: (4, 155, 240, 240) after crop: (4, 133, 152, 125) spacing: [1. 1. 1.]
#
# Case_0006
# Case_0048
# Case_0041
# Case_0055
# before crop: (4, 155, 240, 240) after crop: (4, 138, 161, 129) spacing: [1. 1. 1.]
#
# Case_0013
# Case_0034
# Case_0020
# before crop: (4, 155, 240, 240) after crop: (4, 147, 157, 128) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 174, 143) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 130, 158, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 133, 158, 139) spacing: [1. 1. 1.]
#
# Case_0028
# before crop: (4, 155, 240, 240) after crop: (4, 143, 157, 147) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 167, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 174, 135) spacing: [1. 1. 1.]
#
# Case_0049
# Case_0007
# Case_0042
# before crop: (4, 155, 240, 240) after crop: (4, 128, 173, 131) spacing: [1. 1. 1.]
#
# Case_0056
# Case_0035
# Case_0014
# Case_0021
# before crop: (4, 155, 240, 240) after crop: (4, 138, 182, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 172, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 177, 137) spacing: [1. 1. 1.]
#
# Case_0057
# before crop: (4, 155, 240, 240) after crop: (4, 138, 150, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 174, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 172, 141) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 177, 130) spacing: [1. 1. 1.]
#
# Case_0064
# Case_0071
# before crop: (4, 155, 240, 240) after crop: (4, 137, 152, 135) spacing: [1. 1. 1.]
#
# Case_0078
# Case_0085
# Case_0092
# Case_0099
# Case_0106
# before crop: (4, 155, 240, 240) after crop: (4, 144, 164, 143) spacing: [1. 1. 1.]
#
# Case_0058
# before crop: (4, 155, 240, 240) after crop: (4, 141, 175, 146) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 155, 126) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 167, 127) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 164, 145) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 177, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 175, 141) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 135, 157, 135) spacing: [1. 1. 1.]
#
# Case_0065
# Case_0079
# Case_0086
# Case_0072
# Case_0093
# Case_0059
# Case_0100
# before crop: (4, 155, 240, 240) after crop: (4, 138, 164, 129) spacing: [1. 1. 1.]
#
# Case_0107
# before crop: (4, 155, 240, 240) after crop: (4, 137, 163, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 188, 143) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 179, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 165, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 157, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 164, 140) spacing: [1. 1. 1.]
#
# Case_0066
# before crop: (4, 155, 240, 240) after crop: (4, 138, 183, 141) spacing: [1. 1. 1.]
#
# Case_0073
# Case_0087
# Case_0080
# Case_0060
# Case_0094
# before crop: (4, 155, 240, 240) after crop: (4, 132, 153, 130) spacing: [1. 1. 1.]
#
# Case_0101
# before crop: (4, 155, 240, 240) after crop: (4, 131, 155, 132) spacing: [1. 1. 1.]
#
# Case_0108
# before crop: (4, 155, 240, 240) after crop: (4, 141, 164, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 174, 135) spacing: [1. 1. 1.]
#
# Case_0067
# before crop: (4, 155, 240, 240) after crop: (4, 135, 163, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 175, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 180, 135) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 162, 133) spacing: [1. 1. 1.]
#
# Case_0074
# Case_0088
# Case_0081
# before crop: (4, 155, 240, 240) after crop: (4, 137, 173, 141) spacing: [1. 1. 1.]
#
# Case_0061
# Case_0095
# before crop: (4, 155, 240, 240) after crop: (4, 139, 174, 134) spacing: [1. 1. 1.]
#
# Case_0102
# before crop: (4, 155, 240, 240) after crop: (4, 142, 159, 136) spacing: [1. 1. 1.]
#
# Case_0109
# before crop: (4, 155, 240, 240) after crop: (4, 137, 181, 135) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 131, 161, 131) spacing: [1. 1. 1.]
#
# Case_0068
# before crop: (4, 155, 240, 240) after crop: (4, 143, 188, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 183, 135) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 156, 130) spacing: [1. 1. 1.]
#
# Case_0075
# Case_0089
# Case_0062
# before crop: (4, 155, 240, 240) after crop: (4, 139, 184, 145) spacing: [1. 1. 1.]
#
# Case_0082
# Case_0096
# Case_0110
# before crop: (4, 155, 240, 240) after crop: (4, 142, 181, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 179, 146) spacing: [1. 1. 1.]
#
# Case_0103
# before crop: (4, 155, 240, 240) after crop: (4, 138, 180, 148) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 182, 135) spacing: [1. 1. 1.]
#
# Case_0069
# before crop: (4, 155, 240, 240) after crop: (4, 144, 178, 146) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 173, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 168, 132) spacing: [1. 1. 1.]
#
# Case_0090
# Case_0076
# Case_0063
# Case_0083
# before crop: (4, 155, 240, 240) after crop: (4, 140, 168, 144) spacing: [1. 1. 1.]
#
# Case_0097
# Case_0111
# before crop: (4, 155, 240, 240) after crop: (4, 142, 168, 138) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 175, 134) spacing: [1. 1. 1.]
#
# Case_0104
# before crop: (4, 155, 240, 240) after crop: (4, 136, 170, 135) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 157, 137) spacing: [1. 1. 1.]
#
# Case_0070
# before crop: (4, 155, 240, 240) after crop: (4, 139, 168, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 181, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 186, 139) spacing: [1. 1. 1.]
#
# Case_0091
# Case_0077
# Case_0113
# Case_0084
# before crop: (4, 155, 240, 240) after crop: (4, 124, 165, 129) spacing: [1. 1. 1.]
#
# Case_0098
# before crop: (4, 155, 240, 240) after crop: (4, 144, 172, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 144, 166, 132) spacing: [1. 1. 1.]
#
# Case_0112
# before crop: (4, 155, 240, 240) after crop: (4, 142, 160, 127) spacing: [1. 1. 1.]
#
# Case_0120
# before crop: (4, 155, 240, 240) after crop: (4, 136, 163, 130) spacing: [1. 1. 1.]
#
# Case_0105
# before crop: (4, 155, 240, 240) after crop: (4, 137, 178, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 148, 157, 131) spacing: [1. 1. 1.]
#
# Case_0127
# before crop: (4, 155, 240, 240) after crop: (4, 142, 167, 136) spacing: [1. 1. 1.]
#
# Case_0134
# Case_0114
# Case_0141
# before crop: (4, 155, 240, 240) after crop: (4, 139, 178, 133) spacing: [1. 1. 1.]
#
# Case_0148
# Case_0155
# before crop: (4, 155, 240, 240) after crop: (4, 145, 166, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 175, 135) spacing: [1. 1. 1.]
#
# Case_0121
# before crop: (4, 155, 240, 240) after crop: (4, 144, 169, 142) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 164, 133) spacing: [1. 1. 1.]
#
# Case_0162
# before crop: (4, 155, 240, 240) after crop: (4, 137, 181, 142) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 137, 165, 132) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 166, 131) spacing: [1. 1. 1.]
#
# Case_0115
# Case_0142
# Case_0128
# Case_0135
# before crop: (4, 155, 240, 240) after crop: (4, 137, 174, 141) spacing: [1. 1. 1.]
#
# Case_0156
# Case_0149
# Case_0122
# before crop: (4, 155, 240, 240) after crop: (4, 137, 171, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 165, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 165, 143) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 184, 137) spacing: [1. 1. 1.]
#
# Case_0163
# before crop: (4, 155, 240, 240) after crop: (4, 138, 164, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 180, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 182, 135) spacing: [1. 1. 1.]
#
# Case_0143
# Case_0129
# Case_0116
# before crop: (4, 155, 240, 240) after crop: (4, 139, 165, 137) spacing: [1. 1. 1.]
#
# Case_0136
# Case_0157
# Case_0150
# before crop: (4, 155, 240, 240) after crop: (4, 141, 169, 128) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 175, 132) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 164, 128) spacing: [1. 1. 1.]
#
# Case_0123
# Case_0164
# before crop: (4, 155, 240, 240) after crop: (4, 138, 172, 127) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 133, 154, 125) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 163, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 168, 144) spacing: [1. 1. 1.]
#
# Case_0144
# Case_0117
# before crop: (4, 155, 240, 240) after crop: (4, 140, 168, 133) spacing: [1. 1. 1.]
#
# Case_0130
# Case_0158
# Case_0137
# Case_0151
# before crop: (4, 155, 240, 240) after crop: (4, 138, 151, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 178, 135) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 186, 149) spacing: [1. 1. 1.]
#
# Case_0124
# Case_0165
# before crop: (4, 155, 240, 240) after crop: (4, 143, 169, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 167, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 135, 163, 142) spacing: [1. 1. 1.]
#
# Case_0145
# before crop: (4, 155, 240, 240) after crop: (4, 140, 162, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 171, 137) spacing: [1. 1. 1.]
#
# Case_0118
# Case_0159
# Case_0131
# Case_0138
# Case_0152
# before crop: (4, 155, 240, 240) after crop: (4, 140, 164, 135) spacing: [1. 1. 1.]
#
# Case_0125
# before crop: (4, 155, 240, 240) after crop: (4, 141, 163, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 182, 143) spacing: [1. 1. 1.]
#
# Case_0166
# before crop: (4, 155, 240, 240) after crop: (4, 136, 162, 141) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 139, 160, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 172, 137) spacing: [1. 1. 1.]
#
# Case_0146
# before crop: (4, 155, 240, 240) after crop: (4, 142, 155, 130) spacing: [1. 1. 1.]
#
# Case_0119
# before crop: (4, 155, 240, 240) after crop: (4, 133, 172, 145) spacing: [1. 1. 1.]
#
# Case_0132
# Case_0139
# Case_0160
# before crop: (4, 155, 240, 240) after crop: (4, 141, 160, 128) spacing: [1. 1. 1.]
#
# Case_0153
# Case_0126
# before crop: (4, 155, 240, 240) after crop: (4, 138, 172, 129) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 156, 136) spacing: [1. 1. 1.]
#
# Case_0167
# before crop: (4, 155, 240, 240) after crop: (4, 141, 167, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 179, 130) spacing: [1. 1. 1.]
#
# Case_0147
# before crop: (4, 155, 240, 240) after crop: (4, 140, 163, 129) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 142, 168, 131) spacing: [1. 1. 1.]
#
# Case_0169
# Case_0133
# before crop: (4, 155, 240, 240) after crop: (4, 135, 168, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 184, 132) spacing: [1. 1. 1.]
#
# Case_0140
# Case_0161
# Case_0154
# before crop: (4, 155, 240, 240) after crop: (4, 134, 173, 126) spacing: [1. 1. 1.]
#
# Case_0176
# before crop: (4, 155, 240, 240) after crop: (4, 139, 172, 139) spacing: [1. 1. 1.]
#
# Case_0168
# before crop: (4, 155, 240, 240) after crop: (4, 143, 180, 145) spacing: [1. 1. 1.]
#
# Case_0183
# before crop: (4, 155, 240, 240) after crop: (4, 140, 168, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 147, 174, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 136, 169, 136) spacing: [1. 1. 1.]
#
# Case_0170
# before crop: (4, 155, 240, 240) after crop: (4, 141, 166, 135) spacing: [1. 1. 1.]
#
# Case_0190
# before crop: (4, 155, 240, 240) after crop: (4, 141, 160, 133) spacing: [1. 1. 1.]
#
# Case_0197
# before crop: (4, 155, 240, 240) after crop: (4, 141, 170, 133) spacing: [1. 1. 1.]
#
# Case_0177
# before crop: (4, 155, 240, 240) after crop: (4, 143, 166, 134) spacing: [1. 1. 1.]
#
# Case_0184
# before crop: (4, 155, 240, 240) after crop: (4, 143, 158, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 144, 182, 127) spacing: [1. 1. 1.]
#
# Case_0171
# before crop: (4, 155, 240, 240) after crop: (4, 138, 166, 139) spacing: [1. 1. 1.]
#
# Case_0191
# before crop: (4, 155, 240, 240) after crop: (4, 138, 177, 136) spacing: [1. 1. 1.]
#
# Case_0198
# Case_0178
# before crop: (4, 155, 240, 240) after crop: (4, 143, 167, 127) spacing: [1. 1. 1.]
#
# Case_0185
# before crop: (4, 155, 240, 240) after crop: (4, 135, 175, 131) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 138, 154, 130) spacing: [1. 1. 1.]
#
# Case_0172
# before crop: (4, 155, 240, 240) after crop: (4, 143, 172, 135) spacing: [1. 1. 1.]
#
# Case_0192
# Case_0199
# Case_0179
# before crop: (4, 155, 240, 240) after crop: (4, 147, 166, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 168, 131) spacing: [1. 1. 1.]
#
# Case_0186
# before crop: (4, 155, 240, 240) after crop: (4, 136, 173, 133) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 167, 140) spacing: [1. 1. 1.]
#
# Case_0173
# Case_0193
# before crop: (4, 155, 240, 240) after crop: (4, 150, 180, 138) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 176, 129) spacing: [1. 1. 1.]
#
# Case_0180
# Case_0200
# before crop: (4, 155, 240, 240) after crop: (4, 134, 164, 143) spacing: [1. 1. 1.]
#
# Case_0174
# before crop: (4, 155, 240, 240) after crop: (4, 131, 154, 133) spacing: [1. 1. 1.]
#
# Case_0187
# before crop: (4, 155, 240, 240) after crop: (4, 141, 165, 139) spacing: [1. 1. 1.]
#
# Case_0194
# before crop: (4, 155, 240, 240) after crop: (4, 135, 159, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 146, 161, 141) spacing: [1. 1. 1.]
#
# Case_0181
# Case_0201
# before crop: (4, 155, 240, 240) after crop: (4, 145, 174, 138) spacing: [1. 1. 1.]
#
# Case_0175
# before crop: (4, 155, 240, 240) after crop: (4, 139, 170, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 141, 168, 131) spacing: [1. 1. 1.]
#
# Case_0188
# before crop: (4, 155, 240, 240) after crop: (4, 135, 169, 141) spacing: [1. 1. 1.]
#
# Case_0195
# before crop: (4, 155, 240, 240) after crop: (4, 141, 174, 135) spacing: [1. 1. 1.]
#
# Case_0182
# Case_0202
# before crop: (4, 155, 240, 240) after crop: (4, 141, 168, 141) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 143, 172, 144) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 140, 176, 137) spacing: [1. 1. 1.]
#
# Case_0189
# Case_0196
# before crop: (4, 155, 240, 240) after crop: (4, 141, 173, 134) spacing: [1. 1. 1.]
#
# Case_0203
# before crop: (4, 155, 240, 240) after crop: (4, 137, 170, 127) spacing: [1. 1. 1.]
#
# before crop: (4, 155, 240, 240) after crop: (4, 134, 190, 140) spacing: [1. 1. 1.]
#
#
#
#
#  Task001_MU-Glioma-Post
# number of threads:  (8, 8)
#
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# Are we using the nonzero mask for normalization? OrderedDict([(0, True), (1, True), (2, True), (3, True)])
# the median shape of the dataset is  [139. 168. 135.]
# the max shape in the dataset is  [150. 190. 156.]
# the min shape in the dataset is  [124. 132. 121.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [139. 168. 135.]
# generating configuration for 3d_fullres
# {0: {'batch_size': 2, 'num_pool_per_axis': [5, 5, 5], 'patch_size': array([128, 128, 128]), 'median_patient_size_in_voxels': array([139, 168, 135]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': np.False_, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}}
# transpose forward [np.int64(0), 1, 2]
# transpose backward [np.int64(0), np.int64(1), np.int64(2)]
# Initializing to run preprocessing
# npz folder: /content/nnUNet_raw_data_base/nnUNet_cropped_data/Task001_MU-Glioma-Post
# output_folder: /content/nnUNet_preprocessed/Task001_MU-Glioma-Post
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 167, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 167, 131)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 167, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 167, 130)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 170, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 170, 134)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 158, 138)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 158, 138)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 148, 184, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 148, 184, 133)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 168, 144)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 168, 144)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 144, 156, 156)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 144, 156, 156)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 142, 181, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 142, 181, 136)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0001.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0029.npz
# 1 4632
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0022.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0043.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0050.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0015.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0036.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0008.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 159, 124)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 159, 124)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 172, 127)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 172, 127)}
#
# 1 8620
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0002.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 177, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 177, 130)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0030.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 169, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 169, 140)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0023.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 174, 129)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 174, 129)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 132, 121)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 132, 121)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0044.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0009.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 134, 165, 142)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 134, 165, 142)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0037.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 166, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 166, 130)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0051.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0016.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 133, 171, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 133, 171, 131)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0003.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 157, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 157, 134)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 142, 169, 144)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 142, 169, 144)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0024.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 144, 153, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 144, 153, 137)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0010.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0031.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 170, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 170, 137)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 180, 149)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 180, 149)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0045.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 130, 159, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 130, 159, 134)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0038.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 173, 129)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 173, 129)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0052.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0017.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 176, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 176, 141)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0004.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 134, 168, 126)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 134, 168, 126)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0025.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 186, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 186, 139)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0032.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 157, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 157, 140)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0011.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 133, 158, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 133, 158, 140)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0046.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 171, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 171, 137)}
#
# no resampling necessary
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0053.npz
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 170, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 170, 140)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 149, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 149, 130)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0039.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0018.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 168, 132)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 168, 132)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 177, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 177, 134)}
#
# 1 2444
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0026.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0005.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 161, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 161, 130)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 168, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 168, 134)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0047.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0012.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 169, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 169, 133)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0033.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 133, 152, 125)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 133, 152, 125)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0054.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 171, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 171, 133)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 162, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 162, 139)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0019.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0040.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 161, 129)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 161, 129)}
#
# 1 870
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0027.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 147, 157, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 147, 157, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 174, 143)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 174, 143)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0048.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0006.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 157, 147)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 157, 147)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 133, 158, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 133, 158, 139)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0013.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 167, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 167, 133)}
#
# 1 467
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0055.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0034.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 174, 135)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 174, 135)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 130, 158, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 130, 158, 133)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0020.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 128, 173, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 128, 173, 131)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0041.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0028.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 182, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 182, 133)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0049.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 172, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 172, 136)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0007.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 172, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 172, 141)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 150, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 150, 130)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 174, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 174, 136)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0014.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0035.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0056.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 177, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 177, 137)}
#
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_stage0/Case_0042.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 152, 135)}
# ...
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 169, 136)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 170, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 170, 133)}
#
# normalization...
# normalization done
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0176.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0170.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 168, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 168, 137)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0161.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 147, 174, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 147, 174, 140)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0154.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 160, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 160, 133)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0183.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 166, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 166, 134)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 166, 135)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 166, 135)}
#
# normalization...
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0190.npz
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0168.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 177, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 177, 136)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 144, 182, 127)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 144, 182, 127)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 158, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 158, 139)}
#
# normalization...
# normalization done
# normalization done
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0171.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0177.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0197.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 166, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 166, 139)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0184.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 167, 127)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 167, 127)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0191.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 175, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 175, 131)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 154, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 154, 130)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 147, 166, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 147, 166, 130)}
#
# normalization...
# normalization done
# normalization done
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0198.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0178.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0172.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 172, 135)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 172, 135)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0185.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 168, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 168, 131)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0192.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 173, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 173, 133)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 176, 129)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 176, 129)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 167, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 167, 140)}
#
# normalization...
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0179.npz
# normalization done
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0173.npz
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0199.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 150, 180, 138)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 150, 180, 138)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0186.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 134, 164, 143)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 134, 164, 143)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0193.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 131, 154, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 131, 154, 133)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 159, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 159, 134)}
#
# normalization...
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0180.npz
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0174.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 165, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 165, 139)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0200.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 146, 161, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 146, 161, 141)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 145, 174, 138)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 145, 174, 138)}
#
# normalization...
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0187.npz
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0194.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 170, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 170, 134)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0181.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 169, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 169, 141)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0175.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 168, 131)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 168, 131)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0201.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 174, 135)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 174, 135)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0188.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 168, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 168, 141)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 172, 144)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 172, 144)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0195.npz
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0182.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 176, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 176, 137)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0202.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 173, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 173, 134)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0189.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 170, 127)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 170, 127)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0196.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 134, 190, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 134, 190, 140)}
#
# normalization...
# normalization done
# 1 10000
# saving:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1_2D_stage0/Case_0203.npz

# %%
# !nnUNet_train 3d_fullres nnUNetTrainerV2 Task001_MU-Glioma-Post 0 --npz
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  1
# modalities:  {0: 't1gd', 1: 't1', 2: 't2', 3: 'flair'}
# use_mask_for_norm OrderedDict([(0, True), (1, True), (2, True), (3, True)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'nonCT'), (1, 'nonCT'), (2, 'nonCT'), (3, 'nonCT')])
# stages...
#
# stage:  0
# {'batch_size': 2, 'num_pool_per_axis': [5, 5, 5], 'patch_size': array([128, 128, 128]), 'median_patient_size_in_voxels': array([139, 168, 135]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': np.False_, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1
# ###############################################
# loading dataset
# loading all case properties
# 2025-08-16 12:04:37.742104: Creating new 5-fold cross-validation split...
# 2025-08-16 12:04:37.744010: Desired fold for training: 0
# 2025-08-16 12:04:37.744126: This split has 162 training and 41 validation cases.
# unpacking dataset
# done
# 2025-08-16 12:06:49.511572: lr: 0.01
# 2025-08-16 12:06:49.704256: WARNING!!! You are attempting to run training on a CPU (torch.cuda.is_available() is False). This can be VERY slow!
# /usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/network_trainer.py:404: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.amp_grad_scaler = GradScaler()
# /usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-08-16 12:07:17.818554: Unable to plot network architecture:
# 2025-08-16 12:07:17.819462: No module named 'hiddenlayer'
# 2025-08-16 12:07:17.819661:
# printing the network instead:
#
# 2025-08-16 12:07:17.819795: Generic_UNet(
#   (conv_blocks_localization): ModuleList(
#     (0): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (conv_blocks_context): ModuleList(
#     (0): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (1): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (2): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (3): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (4): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (td): ModuleList()
#   (tu): ModuleList(
#     (0): ConvTranspose3d(320, 320, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (1): ConvTranspose3d(320, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (2): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (3): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (4): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#   )
#   (seg_outputs): ModuleList(
#     (0): Conv3d(320, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (1): Conv3d(256, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (2): Conv3d(128, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (3): Conv3d(64, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (4): Conv3d(32, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   )
# )
# 2025-08-16 12:07:17.932731:
#
# 2025-08-16 12:07:17.936782:
# epoch:  0
# Exception in thread Thread-4 (results_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/batchgenerators/dataloading/multi_threaded_augmenter.py", line 92, in results_loop
#     raise RuntimeError("One or more background workers are no longer alive. Exiting. Please check the print"
# RuntimeError: One or more background workers are no longer alive. Exiting. Please check the print statements above for the actual error message
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNet_train", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nnunet/run/run_training.py", line 182, in main
#     trainer.run_training()
#   File "/usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/nnUNetTrainerV2.py", line 440, in run_training
#     ret = super().run_training()
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/nnUNetTrainer.py", line 318, in run_training
#     super(nnUNetTrainer, self).run_training()
#   File "/usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/network_trainer.py", line 456, in run_training
#     l = self.run_iteration(self.tr_gen, True)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/nnUNetTrainerV2.py", line 232, in run_iteration
#     data_dict = next(data_generator)
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/batchgenerators/dataloading/multi_threaded_augmenter.py", line 204, in __next__
#     item = self.__get_next_item()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/batchgenerators/dataloading/multi_threaded_augmenter.py", line 189, in __get_next_item
#     raise RuntimeError("One or more background workers are no longer alive. Exiting. Please check the "
# RuntimeError: One or more background workers are no longer alive. Exiting. Please check the print statements above for the actual error message
# Exception in thread Thread-5 (results_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/batchgenerators/dataloading/multi_threaded_augmenter.py", line 92, in results_loop
#     raise RuntimeError("One or more background workers are no longer alive. Exiting. Please check the print"
# RuntimeError: One or more background workers are no longer alive. Exiting. Please check the print statements above for the actual error message

# %%
# !export nnUNet_n_proc_DA=1 && nnUNet_train 3d_fullres nnUNetTrainerV2 Task001_MU-Glioma-Post 0 --npz
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  1
# modalities:  {0: 't1gd', 1: 't1', 2: 't2', 3: 'flair'}
# use_mask_for_norm OrderedDict([(0, True), (1, True), (2, True), (3, True)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'nonCT'), (1, 'nonCT'), (2, 'nonCT'), (3, 'nonCT')])
# stages...
#
# stage:  0
# {'batch_size': 2, 'num_pool_per_axis': [5, 5, 5], 'patch_size': array([128, 128, 128]), 'median_patient_size_in_voxels': array([139, 168, 135]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': np.False_, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/nnUNetData_plans_v2.1
# ###############################################
# loading dataset
# loading all case properties
# 2025-08-16 12:18:36.490379: Using splits from existing split file: /content/nnUNet_preprocessed/Task001_MU-Glioma-Post/splits_final.pkl
# 2025-08-16 12:18:36.499692: The split file contains 5 splits.
# 2025-08-16 12:18:36.499910: Desired fold for training: 0
# 2025-08-16 12:18:36.500006: This split has 162 training and 41 validation cases.
# unpacking dataset
# done
# 2025-08-16 12:18:39.731138: lr: 0.01
# 2025-08-16 12:18:39.940031: WARNING!!! You are attempting to run training on a CPU (torch.cuda.is_available() is False). This can be VERY slow!
# /usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/network_trainer.py:404: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.amp_grad_scaler = GradScaler()
# /usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-08-16 12:18:46.856646: Unable to plot network architecture:
# 2025-08-16 12:18:46.856888: No module named 'hiddenlayer'
# 2025-08-16 12:18:46.856971:
# printing the network instead:
#
# 2025-08-16 12:18:46.857069: Generic_UNet(
#   (conv_blocks_localization): ModuleList(
#     (0): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (conv_blocks_context): ModuleList(
#     (0): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (1): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (2): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (3): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (4): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (td): ModuleList()
#   (tu): ModuleList(
#     (0): ConvTranspose3d(320, 320, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (1): ConvTranspose3d(320, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (2): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (3): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (4): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#   )
#   (seg_outputs): ModuleList(
#     (0): Conv3d(320, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (1): Conv3d(256, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (2): Conv3d(128, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (3): Conv3d(64, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (4): Conv3d(32, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   )
# )
# 2025-08-16 12:18:46.865345:
#
# 2025-08-16 12:18:46.866557:
# epoch:  0
# /usr/local/lib/python3.11/dist-packages/nnunet/training/network_training/nnUNetTrainerV2.py:246: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /usr/local/lib/python3.11/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(

# %% [markdown]
# **trick to check progress quickly**
